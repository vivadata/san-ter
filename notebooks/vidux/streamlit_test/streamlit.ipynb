# %%
import streamlit as st
import pandas as pd

# ------------------------------------------------------
# 1. Chargement des données
# ------------------------------------------------------
@st.cache_data
def load_data(path: str = "rpps_long_clean.csv") -> pd.DataFrame:
    # adapte les dtypes si besoin
    df = pd.read_csv(
        path,
        dtype={
            "dept_code": "string",
            "dept_code_clean": "string",
        }
    )
    return df

df = load_data()  # <-- lit rpps_long_clean.csv dans le même dossier


# ------------------------------------------------------
# 2. Titre et description
# ------------------------------------------------------
st.title("Densité et effectifs des médecins par spécialité (RPPS)")

st.write(
    "Données issues du fichier **rpps_long_clean.csv** "
    "avec agrégation par **spécialité** et **département**."
)


# ------------------------------------------------------
# 3. Menu déroulant des spécialités
# ------------------------------------------------------
# on suppose que ta colonne s'appelle bien 'specialite'
specialites = sorted(df["specialite"].dropna().unique().tolist())

selected_specialite = st.selectbox(
    "Choisir une spécialité",
    options=specialites,
    index=0,
)

# Choix de l'indicateur
metric = st.radio(
    "Indicateur à afficher",
    options=["densite", "effectif"],
    format_func=lambda x: "Densité (pour 100 000 hab.)" if x == "densite" else "Effectif (nombre de médecins)",
    horizontal=True,
)


# ------------------------------------------------------
# 4. Filtrage des données
# ------------------------------------------------------
df_filtered = (
    df[df["specialite"] == selected_specialite]
    .copy()
)

# si jamais plusieurs lignes par dept (par ex. doublons),
# on agrège par département
df_grouped = (
    df_filtered
    .groupby("dept_code_clean", as_index=False)[metric]
    .sum()
    .sort_values("dept_code_clean")
)

if df_grouped.empty:
    st.warning("Aucune donnée trouvée pour cette spécialité.")
    st.stop()


# ------------------------------------------------------
# 5. Tableau
# ------------------------------------------------------
st.subheader(f"Tableau – {selected_specialite}")

st.dataframe(
    df_grouped,
    use_container_width=True,
)


# ------------------------------------------------------
# 6. Graphique
# ------------------------------------------------------
st.subheader(f"Graphique – {metric} par département")

st.bar_chart(
    df_grouped.set_index("dept_code_clean")[metric]
)
# Out:
# 2025-11-19 15:39:18.144 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-11-19 15:39:18.148 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-11-19 15:39:18.150 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.876
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/vidux/.pyenv/versions/Artefact/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-11-19 15:39:18.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.978 Session state does not function when running a script without `streamlit run`
# 2025-11-19 15:39:18.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:18.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:19.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:19.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:19.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:19.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:19.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:19.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:19.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:19.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:19.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:19.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:20.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-19 15:39:20.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
